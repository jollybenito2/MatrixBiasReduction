# %%
# -*- coding: utf-8 -*-
"""
Created on Tue Jan 25 19:01:09 2022

@author: benit
"""
## Recolectar Datos Reales
import os
from pathlib import Path
#import investpy
import datetime as dt
import yfinance as yf
import pandas as pd
# GET RECENT STOCK INFO.
# PREVIOUSLY SELECT A SOURCE OF DATA. (Yahoo Finance, 
# Investing, Interactive Brokers)

# %%
os.chdir(r'C:/Users/52999/Desktop/MatrixOptim')

Stocks1=pd.read_csv('AccionesBMV.csv', dtype = str, header=0)

stocks2=['AAPL', 'BAC', 'AMZN', 'T', 'GOOG', 'MO', 'DAL',
        'AA', 'AXP', 'DD', 'BABA', 'ABT', 'UA', 'AMAT','AMGN',
            'AAL','AIG','ALL','ADBE','GOOGL', 'ACN','ABBV','MT',
            'LLY','APA','ADP','AKAM','NLY','ATVI',
            'ADSK','ADM','GPS','WBA','ARNA','LUV','ACAD','PANW',
            'AEP','AVGO','EA','DB','PBR','RIOT','GE',
            'AEM','APD','AMBA','NVS','GSAT','ANF',
            'UBS','SAVE','F','AMX','ERC',
            'AOS','AAP','AES','AFL','A','APD','ALK','ALB','ARE',
             'LNT','GOOG','AMT','AWK','AMP','ABC',
             'AME','APH','ADI','ANSS','ANTM','APTV','AJG','SPGI',
             'AZO','AVB','AVY','BKR','BLL','BAC','BK','BAX',
             'BDX','BBY','BLK','BA','BWA','CPB','SPY']
y = Stocks1.shape[0]
for x in stocks2:
    Stocks1 = Stocks1.append(pd.Series(data = {'Acciones':x}), ignore_index=True)

# %%
def get_data_from_yahoo(tickers):
    start = dt.datetime(2019, 1, 1)
    end = dt.datetime(2022, 3, 31)
    for ticker in tickers:
        # just in case your connection breaks, we'd like to save our progress!
        if not os.path.exists('BMV/{}.csv'.format(ticker.rstrip("\n"))):
            #df = pdr.DataReader(ticker.rstrip("\n"), start, 
            #           end, data_source='yahoo')['Adj Close']
            df = yf.download(ticker.rstrip("\n"), start, end, "1m")      
            df.reset_index(inplace=True)
            df.set_index("Date", inplace=True)
            # Check for empty df and do not save them.
            if df.empty:
                print('DataFrame is empty!')
            else: 
                df.to_csv('BMV/{}.csv'.format(ticker.rstrip("\n")))
        else:
            print('Already have {}'.format(ticker.rstrip("\n")))

#get_data_from_yahoo(list(Stocks1['Acciones']))
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SITES1A-1.MX: No data found for this date range, symbol may be delisted
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Already have APD
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Already have GOOG
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Already have BAC
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
def get_data_from_yahoo(tickers):
    start = dt.datetime(2022, 2, 1)
    end = dt.datetime(2022, 2, 7)
    for ticker in tickers:
        # just in case your connection breaks, we'd like to save our progress!
        if not os.path.exists('BMV_Minutes/{}.csv'.format(ticker.rstrip("\n"))):
            #df = pdr.DataReader(ticker.rstrip("\n"), start, 
            #           end, data_source='yahoo')['Adj Close']
            df = yf.download(ticker.rstrip("\n"), start, end, interval = "1m")      
            df.reset_index(inplace=True)
            df.set_index("Date", inplace=True)
            # Check for empty df and do not save them.
            if df.empty:
                print('DataFrame is empty!')
            else: 
                df.to_csv('BMV_Minutes/{}.csv'.format(ticker.rstrip("\n")))
        else:
            print('Already have {}'.format(ticker.rstrip("\n")))

get_data_from_yahoo(list(Stocks1['Acciones']))
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - WALMEX.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - VOLARA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - VESTA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - TLEVISACPO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - SITES1A-1.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - RA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - Q.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PINFRA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - PE&OLES.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ORBIA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - OMAB.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - MEGACPO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LIVEPOLC-1.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - LABB.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - KOF: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - KIMBERA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GRUMAB.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GMEXICOB.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GFNORTEO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GFINBURO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GCC.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GCARSOA1.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - GAPB.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - FEMSAUBD.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ELEKTRA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CUERVO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CEMEXCPO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BOLSAA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BIMBOA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BBAJIOO.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ASURB.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMXL.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALSEA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALFAA.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AC.MX: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAPL: 1m data not available for startTime=1643695200 and endTime=1648706400. Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# DataFrame is empty!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2000/3743320618.py in <module>
#      18             print('Already have {}'.format(ticker.rstrip("\n")))
#      19
# ---> 20 get_data_from_yahoo(list(Stocks1['Acciones']))
#
# ~\AppData\Local\Temp/ipykernel_2000/3743320618.py in get_data_from_yahoo(tickers)
#       7             #df = pdr.DataReader(ticker.rstrip("\n"), start,
#       8             #           end, data_source='yahoo')['Adj Close']
# ----> 9             df = yf.download(ticker.rstrip("\n"), start, end, interval = "1m")
#      10             df.reset_index(inplace=True)
#      11             df.set_index("Date", inplace=True)
#
# ~\anaconda3\lib\site-packages\yfinance\multi.py in download(tickers, start, end, actions, threads, group_by, auto_adjust, back_adjust, progress, period, show_errors, interval, prepost, proxy, rounding, timeout, **kwargs)
#     110                                    rounding=rounding, timeout=timeout)
#     111         while len(shared._DFS) < len(tickers):
# --> 112             _time.sleep(0.01)
#     113
#     114     # download synchronously
#
# KeyboardInterrupt:
